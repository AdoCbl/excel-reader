# %%
import langextract

# %%
equation = "(current month end discount factor / prior month end discount factor - 1) * 12"

# %%
# Out:
# 2025-08-14 23:33:33,433 - langextract.debug - DEBUG - [langextract.inference] CALL: BaseLanguageModel.__init__(self=<OllamaLanguageModel>, constraint=Constraint(co...NONE: 'none'>), kwargs={})
# 2025-08-14 23:33:33,434 - langextract.debug - DEBUG - [langextract.inference] RETURN: BaseLanguageModel.__init__ -> None (0.0 ms)
# 2025-08-14 23:33:33,435 - langextract.debug - DEBUG - [langextract.inference] CALL: BaseLanguageModel.apply_schema(self=<OllamaLanguageModel>, schema_instance=<langextract....t 0x1125dde50>)
# 2025-08-14 23:33:33,435 - langextract.debug - DEBUG - [langextract.inference] RETURN: BaseLanguageModel.apply_schema -> None (0.0 ms)
# DEBUG:absl:Initialized Annotator with prompt:
# variable names
#
# Examples
# Q: revenue - cogs
# A: {
#   "extractions": [
#     {
#       "variable": "revenue",
#       "variable_attributes": {}
#     },
#     {
#       "variable": "cogs",
#       "variable_attributes": {}
#     }
#   ]
# }
#
# Q:
# A:
# ...
